# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_set = pd.read_csv("Desktop/practical2/train.csv", header=0)

# %%
train_set.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont2     cont3  \
# 0   0    A    I    A    B    B   BI    A    S    Q  ...  0.759439  0.795549
# 1   1    A    I    A    A    E   BI    K    W   AD  ...  0.386385  0.541366
# 2   2    A    K    A    A    E   BI    A    E   BM  ...  0.343255  0.616352
# 3   3    A    K    A    C    E   BI    A    Y   AD  ...  0.831147  0.807807
# 4   4    A    I    G    B    E   BI    C    G    Q  ...  0.338818  0.277308
#
#       cont4     cont5     cont6     cont7     cont8     cont9    cont10 target
# 0  0.681917  0.621672  0.592184  0.791921  0.815254  0.965006  0.665915      0
# 1  0.388982  0.357778  0.600044  0.408701  0.399353  0.927406  0.493729      0
# 2  0.793687  0.552877  0.352113  0.388835  0.412303  0.292696  0.549452      0
# 3  0.800032  0.619147  0.221789  0.897617  0.633669  0.760318  0.934242      0
# 4  0.610578  0.128291  0.578764  0.279167  0.351103  0.357084  0.328960      1
#
# [5 rows x 32 columns]

# %%
len(train_set)
# Out:
# 300000

# %%
#EDA for continuous variables
X_train_cont= train_set[train_set.columns[20:31]]
X_train_cont.head()
# Out:
#       cont0     cont1     cont2     cont3     cont4     cont5     cont6  \
# 0  0.629858  0.855349  0.759439  0.795549  0.681917  0.621672  0.592184
# 1  0.370727  0.328929  0.386385  0.541366  0.388982  0.357778  0.600044
# 2  0.502272  0.322749  0.343255  0.616352  0.793687  0.552877  0.352113
# 3  0.934242  0.707663  0.831147  0.807807  0.800032  0.619147  0.221789
# 4  0.254427  0.274514  0.338818  0.277308  0.610578  0.128291  0.578764
#
#       cont7     cont8     cont9    cont10
# 0  0.791921  0.815254  0.965006  0.665915
# 1  0.408701  0.399353  0.927406  0.493729
# 2  0.388835  0.412303  0.292696  0.549452
# 3  0.897617  0.633669  0.760318  0.934242
# 4  0.279167  0.351103  0.357084  0.328960

# %%
#summary and histogram
print(train_set['cont0'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont0'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.504749
# std           0.206788
# min          -0.049562
# 25%           0.344985
# 50%           0.479650
# 75%           0.637657
# max           1.004559
# Name: cont0, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont1'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont1'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.494073
# std           0.213037
# min           0.084480
# 25%           0.317363
# 50%           0.463170
# 75%           0.693992
# max           1.009958
# Name: cont1, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont2'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont2'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.516632
# std           0.214851
# min           0.094493
# 25%           0.326047
# 50%           0.471247
# 75%           0.704625
# max           1.016600
# Name: cont2, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont3'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont3'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.474235
# std           0.216636
# min          -0.045316
# 25%           0.292249
# 50%           0.387564
# 75%           0.644950
# max           0.952187
# Name: cont3, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont4'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont4'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.504848
# std           0.227474
# min           0.168071
# 25%           0.279303
# 50%           0.479858
# 75%           0.725779
# max           0.858578
# Name: cont4, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont5'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont5'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.502257
# std           0.241243
# min          -0.036379
# 25%           0.276442
# 50%           0.554768
# 75%           0.735225
# max           0.853022
# Name: cont5, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont6'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont6'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.488229
# std           0.211335
# min           0.005199
# 25%           0.323914
# 50%           0.518089
# 75%           0.608537
# max           0.966553
# Name: cont6, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont7'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont7'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.501739
# std           0.203496
# min           0.090901
# 25%           0.353054
# 50%           0.435404
# 75%           0.642023
# max           1.035818
# Name: cont7, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont8'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont8'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.488074
# std           0.179048
# min           0.024139
# 25%           0.358915
# 50%           0.410908
# 75%           0.612725
# max           1.055885
# Name: cont8, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont9'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont9'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.469496
# std           0.194516
# min           0.214866
# 25%           0.309934
# 50%           0.407477
# 75%           0.586793
# max           1.005652
# Name: cont9, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(train_set['cont10'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(train_set['cont10'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    300000.000000
# mean          0.508230
# std           0.203393
# min           0.097789
# 25%           0.368312
# 50%           0.446576
# 75%           0.581957
# max           1.011331
# Name: cont10, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#checking the incidence of outliers
plt.figure(figsize=(9, 8))
sns.boxplot(data=X_train_cont, orient="h", palette="Set2")
# Out:
# <AxesSubplot:>

# %%
train_set['target'].value_counts()
# Out:
# 0    220539
# 1     79461
# Name: target, dtype: int64

# %%
#complete view of numerical features
X_train_cont.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
X_train_cont.corr().round(3)
# Out:
#         cont0  cont1  cont2  cont3  cont4  cont5  cont6  cont7  cont8  cont9  \
# cont0   1.000  0.474  0.495  0.549  0.156 -0.169 -0.437  0.740  0.368  0.415
# cont1   0.474  1.000  0.862  0.257  0.134  0.186  0.116  0.581  0.673  0.393
# cont2   0.495  0.862  1.000  0.287  0.159  0.158  0.067  0.606  0.663  0.399
# cont3   0.549  0.257  0.287  1.000  0.223 -0.069 -0.430  0.642  0.189  0.383
# cont4   0.156  0.134  0.159  0.223  1.000  0.038 -0.081  0.232  0.065  0.161
# cont5  -0.169  0.186  0.158 -0.069  0.038  1.000  0.439 -0.094  0.141  0.121
# cont6  -0.437  0.116  0.067 -0.430 -0.081  0.439  1.000 -0.362  0.123 -0.126
# cont7   0.740  0.581  0.606  0.642  0.232 -0.094 -0.362  1.000  0.479  0.443
# cont8   0.368  0.673  0.663  0.189  0.065  0.141  0.123  0.479  1.000  0.293
# cont9   0.415  0.393  0.399  0.383  0.161  0.121 -0.126  0.443  0.293  1.000
# cont10  0.808  0.471  0.507  0.611  0.208 -0.161 -0.443  0.775  0.382  0.453
#
#         cont10
# cont0    0.808
# ...

# %%
corr = X_train_cont.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
plt.figure(figsize=(9, 8))
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
#Categorical variables EDA
X_train_cat= train_set[train_set.columns[1:20]]
X_train_cat.head()
# Out:
#   cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10 cat11 cat12 cat13  \
# 0    A    I    A    B    B   BI    A    S    Q    A    LO     A     A     A
# 1    A    I    A    A    E   BI    K    W   AD    F    HJ     A     B     A
# 2    A    K    A    A    E   BI    A    E   BM    L    DJ     A     B     A
# 3    A    K    A    C    E   BI    A    Y   AD    F    KV     A     A     A
# 4    A    I    G    B    E   BI    C    G    Q    A    DP     A     A     A
#
#   cat14 cat15 cat16 cat17 cat18
# 0     A     B     D     D     B
# 1     B     D     B     D     B
# 2     A     B     D     D     B
# 3     A     B     D     D     B
# 4     B     B     B     D     B

# %%
#summary
print(X_train_cat.describe())
# Out:
#           cat0    cat1    cat2    cat3    cat4    cat5    cat6    cat7  \
# count   300000  300000  300000  300000  300000  300000  300000  300000
# unique       2      15      19      13      20      84      16      51
# top          A       I       A       A       E      BI       A      AH
# freq    223525   90809  168694  187251  129385  238563  187896   45818
#
#           cat8    cat9   cat10   cat11   cat12   cat13   cat14   cat15  \
# count   300000  300000  300000  300000  300000  300000  300000  300000
# unique      61      19     299       2       2       2       2       4
# top         BM       A      DJ       A       A       A       A       B
# freq     42380  201945   31584  258932  257139  292712  160166  203574
#
#          cat16   cat17   cat18
# count   300000  300000  300000
# unique       4       4       4
# top          D       D       B
# freq    206906  247125  255482

# %%
#counting categorical values in each column & frequency
X_train_cat['cat0'].value_counts()
# Out:
# A    223525
# B     76475
# Name: cat0, dtype: int64

# %%
sns.countplot(data = train_set, x='cat0')
# Out:
# <AxesSubplot:xlabel='cat0', ylabel='count'>

# %%
#Checking which categorical observation corresponds to which response (0,1)
sns.countplot(data = train_set, x="cat0", hue="target")
# Out:
# <AxesSubplot:xlabel='cat0', ylabel='count'>

# %%
X_train_cat['cat1'].value_counts()
# Out:
# I    90809
# F    43818
# K    41870
# L    31891
# H    17257
# N    13231
# M    11354
# G    11248
# A    10547
# J    10036
# O     8740
# B     6847
# C     1703
# D      414
# E      235
# Name: cat1, dtype: int64

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x='cat1')
# Out:
# <AxesSubplot:xlabel='cat1', ylabel='count'>

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x="cat1", hue="target")
# Out:
# <AxesSubplot:xlabel='cat1', ylabel='count'>

# %%
X_train_cat['cat2'].value_counts()
# Out:
# A    168694
# C     38875
# D     22720
# G     18225
# Q     10901
# F      9877
# J      9102
# M      8068
# I      5287
# L      3997
# O      2749
# N       340
# H       219
# B       218
# S       197
# U       166
# R       129
# K       126
# E       110
# Name: cat2, dtype: int64

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x='cat2')
# Out:
# <AxesSubplot:xlabel='cat2', ylabel='count'>

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x="cat2", hue="target")
# Out:
# <AxesSubplot:xlabel='cat2', ylabel='count'>

# %%
X_train_cat['cat3'].value_counts()
# Out:
# A    187251
# B     79951
# C     15957
# D      8676
# E      3318
# F      2489
# K       846
# G       372
# L       292
# J       286
# H       274
# I       177
# N       111
# Name: cat3, dtype: int64

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x="cat3")
# Out:
# <AxesSubplot:xlabel='cat3', ylabel='count'>

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x="cat3", hue="target")
# Out:
# <AxesSubplot:xlabel='cat3', ylabel='count'>

# %%
X_train_cat['cat4'].value_counts()
# Out:
# E    129385
# F     76678
# G     30754
# D     27919
# H     23388
# J      4307
# I      3241
# K      1481
# M       547
# C       506
# O       330
# B       301
# S       285
# T       215
# L       214
# Q       117
# P       100
# A        92
# N        81
# R        59
# Name: cat4, dtype: int64

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x="cat4")
# Out:
# <AxesSubplot:xlabel='cat4', ylabel='count'>

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x="cat4")
# Out:
# <AxesSubplot:xlabel='cat4', ylabel='count'>

# %%
X_train_cat['cat5'].value_counts()
# Out:
# BI    238563
# AB     41639
# BU      6740
# K       2713
# G        683
#        ...
# ZZ        25
# B         24
# AG        19
# BP        19
# CB        18
# Name: cat5, Length: 84, dtype: int64

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat5")
# Out:
# <AxesSubplot:xlabel='cat5', ylabel='count'>

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat5", hue="target")
# Out:
# <AxesSubplot:xlabel='cat5', ylabel='count'>

# %%
X_train_cat['cat6'].value_counts()
# Out:
# A    187896
# C     71427
# E     16581
# G     11198
# I      6648
# M      2182
# K      1552
# O       673
# S       583
# F       312
# D       214
# Y       212
# B       172
# U       155
# Q       124
# W        71
# Name: cat6, dtype: int64

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x="cat6")
# Out:
# <AxesSubplot:xlabel='cat6', ylabel='count'>

# %%
plt.figure(figsize = (10,9))
sns.countplot(data = train_set, x="cat6", hue="target")
# Out:
# <AxesSubplot:xlabel='cat6', ylabel='count'>

# %%
X_train_cat['cat7'].value_counts()
# Out:
# AH    45818
# E     39601
# AS    25326
# J     16135
# AN    16097
# U     15674
# N     14983
# AF    11455
# AK     9697
# AV     7958
# S      7921
# AI     7668
# A      6432
# K      6264
# Y      5896
# G      5656
# F      5550
# AW     5322
# C      4324
# AA     3692
# R      2991
# AX     2635
# O      2538
# AP     2311
# AD     1826
# V      1798
# AY     1749
# AO     1734
# AG     1706
# H      1692
# AL     1572
# W      1525
# B      1408
# Q      1306
# AM     1183
# AR     1121
# L       941
# AT      918
# M       907
# D       835
# BA      781
# AU      671
# X       662
# AC      660
# I       640
# P       611
# AB      539
# AE      458
# T       379
# AJ      229
# AQ      205
# Name: cat7, dtype: int64

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat7")
# Out:
# <AxesSubplot:xlabel='cat7', ylabel='count'>

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat7", hue="target")
# Out:
# <AxesSubplot:xlabel='cat7', ylabel='count'>

# %%
X_train_cat['cat8'].value_counts()
# Out:
# BM    42380
# AE    24442
# AX    22129
# Y     20864
# H     15561
#       ...
# AQ       69
# T        67
# B        57
# AC       57
# AR       33
# Name: cat8, Length: 61, dtype: int64

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat8")
# Out:
# <AxesSubplot:xlabel='cat8', ylabel='count'>

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat8", hue="target")
# Out:
# <AxesSubplot:xlabel='cat8', ylabel='count'>

# %%
X_train_cat['cat9'].value_counts()
# Out:
# A    201945
# E     33046
# C     23360
# F     14371
# J      8982
# I      7931
# N      4785
# L      2957
# R       862
# V       360
# B       280
# G       214
# Q       211
# D       189
# W       125
# O       122
# U       101
# X        99
# S        60
# Name: cat9, dtype: int64

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat9")
# Out:
# <AxesSubplot:xlabel='cat9', ylabel='count'>

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat9", hue="target")
# Out:
# <AxesSubplot:xlabel='cat9', ylabel='count'>

# %%
X_train_cat['cat10'].value_counts()
# Out:
# DJ    31584
# HK    30998
# DP    23679
# GS    16619
# CR    14382
#       ...
# MK        1
# FW        1
# IL        1
# ML        1
# GG        1
# Name: cat10, Length: 299, dtype: int64

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat10")
# Out:
# <AxesSubplot:xlabel='cat10', ylabel='count'>

# %%
plt.figure(figsize = (30,9))
sns.countplot(data = train_set, x="cat10", hue="target")
# Out:
# <AxesSubplot:xlabel='cat10', ylabel='count'>

# %%
X_train_cat['cat11'].value_counts()
# Out:
# A    258932
# B     41068
# Name: cat11, dtype: int64

# %%
sns.countplot(data = train_set, x="cat11")
# Out:
# <AxesSubplot:xlabel='cat11', ylabel='count'>

# %%
sns.countplot(data = train_set, x="cat11", hue="target")
# Out:
# <AxesSubplot:xlabel='cat11', ylabel='count'>

# %%
X_train_cat['cat12'].value_counts()
# Out:
# A    257139
# B     42861
# Name: cat12, dtype: int64

# %%
sns.countplot(data = train_set, x="cat12")
# Out:
# <AxesSubplot:xlabel='cat12', ylabel='count'>

# %%
sns.countplot(data = train_set, x="cat12", hue="target")
# Out:
# <AxesSubplot:xlabel='cat12', ylabel='count'>

# %%
X_train_cat['cat13'].value_counts()
# Out:
# A    292712
# B      7288
# Name: cat13, dtype: int64

# %%
sns.countplot(data = train_set, x="cat13")
# Out:
# <AxesSubplot:xlabel='cat13', ylabel='count'>

# %%
sns.countplot(data = train_set, x="cat13", hue="target")
# Out:
# <AxesSubplot:xlabel='cat13', ylabel='count'>

# %%
X_train_cat['cat14'].value_counts()
# Out:
# A    160166
# B    139834
# Name: cat14, dtype: int64

# %%
sns.countplot(data = train_set, x="cat14")
# Out:
# <AxesSubplot:xlabel='cat14', ylabel='count'>

# %%
sns.countplot(data = train_set, x="cat14", hue="target")
# Out:
# <AxesSubplot:xlabel='cat14', ylabel='count'>

# %%
X_train_cat['cat15'].value_counts()
# Out:
# B    203574
# D     83188
# A     11072
# C      2166
# Name: cat15, dtype: int64

# %%
sns.countplot(data = train_set, x="cat15")
# Out:
# <AxesSubplot:xlabel='cat15', ylabel='count'>

# %%
sns.countplot(data = train_set, x="cat15", hue="target")
# Out:
# <AxesSubplot:xlabel='cat15', ylabel='count'>

# %%
X_train_cat['cat16'].value_counts()
# Out:
# D    206906
# B     84541
# C      5369
# A      3184
# Name: cat16, dtype: int64

# %%
sns.countplot(data = train_set, x="cat16")
# Out:
# <AxesSubplot:xlabel='cat16', ylabel='count'>

# %%
sns.countplot(data = train_set, x="cat16", hue="target")
# Out:
# <AxesSubplot:xlabel='cat16', ylabel='count'>

# %%
X_train_cat['cat17'].value_counts()
# Out:
# D    247125
# B     26136
# C     25325
# A      1414
# Name: cat17, dtype: int64

# %%
sns.countplot(data = train_set, x="cat17")
# Out:
# <AxesSubplot:xlabel='cat17', ylabel='count'>

# %%
sns.countplot(data = train_set, x="cat17", hue="target")
# Out:
# <AxesSubplot:xlabel='cat17', ylabel='count'>

# %%
X_train_cat['cat18'].value_counts()
# Out:
# B    255482
# D     22394
# C     21414
# A       710
# Name: cat18, dtype: int64

# %%
sns.countplot(data = train_set, x="cat18")
# Out:
# <AxesSubplot:xlabel='cat18', ylabel='count'>

# %%
sns.countplot(data = train_set, x="cat18", hue="target")
# Out:
# <AxesSubplot:xlabel='cat18', ylabel='count'>

# %%
#NEED: 

#choose which feature (categorical or numerical), state why (if any) and drop (reduce dimensionality)
#Once reduced the training dataset, choose a range of models/classifiers to get predictions. 
#Given the binary outcome binomial and logistic models should be included.

#perform VIF to check for collinearity and then reduce again the dataset and redo.
#Upload predictions from our range of models on Kaggle and note down accuracy scores given.

# %%
#my draft (DO WE NEED TO DROP "ID"?)
X=train_set[train_set.columns[1:31]]

y_train = train_set[["target"]]
y_train.head()
# Out:
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %%
X_train_cont.corr().round(3)
# Out:
#         cont0  cont1  cont2  cont3  cont4  cont5  cont6  cont7  cont8  cont9  \
# cont0   1.000  0.474  0.495  0.549  0.156 -0.169 -0.437  0.740  0.368  0.415
# cont1   0.474  1.000  0.862  0.257  0.134  0.186  0.116  0.581  0.673  0.393
# cont2   0.495  0.862  1.000  0.287  0.159  0.158  0.067  0.606  0.663  0.399
# cont3   0.549  0.257  0.287  1.000  0.223 -0.069 -0.430  0.642  0.189  0.383
# cont4   0.156  0.134  0.159  0.223  1.000  0.038 -0.081  0.232  0.065  0.161
# cont5  -0.169  0.186  0.158 -0.069  0.038  1.000  0.439 -0.094  0.141  0.121
# cont6  -0.437  0.116  0.067 -0.430 -0.081  0.439  1.000 -0.362  0.123 -0.126
# cont7   0.740  0.581  0.606  0.642  0.232 -0.094 -0.362  1.000  0.479  0.443
# cont8   0.368  0.673  0.663  0.189  0.065  0.141  0.123  0.479  1.000  0.293
# cont9   0.415  0.393  0.399  0.383  0.161  0.121 -0.126  0.443  0.293  1.000
# cont10  0.808  0.471  0.507  0.611  0.208 -0.161 -0.443  0.775  0.382  0.453
#
#         cont10
# cont0    0.808
# ...

# %%
#DRAFT, MISTAKE
#Some commonly used correlation filtering methods have a tendency to drop more features than required. 
#This problem is amplified as datasets become larger and with more pairwise correlations above a specified threshold.
#If we drop more variables than necessary, less information will be available potentially leading to suboptimal model performance. 

#1 instead of 0.9, lower triangle instead of upper, 0.4 instead of 0.6

def corr_notok(X_train_cont, cut = 1) :
        
    # Get correlation matrix and lower triagle
    corr_matrix = X_train_cont.corr().abs()
    average_corr = corr_matrix.mean(axis = 1)
    lower_matrix = corr_matrix.where(np.tril(np.ones(corr_matrix.shape), k=1).astype(bool))
    
    drop = list()

        
    # For loop implements this pseudocode
    # For every cell in the lower triangle: 
        # If cell.value > 0.4: 
                # If mean(row_correlation) > mean(column_correlation):drop(column)
# Else: drop(row)
    for row in range(len(lower_matrix)-1):
        col_index = row + 1
        for col in range (col_index, len(lower_matrix)):
            if(corr_matrix.iloc[row, col] > cut):
                if(average_corr.iloc[row] > average_corr.iloc[col]): 
                    drop.append(row)
                else: 
                    drop.append(col)
    
    drop_set = list(set(drop))
    # dropcols_idx = drop_set
    dropcols_featurename = list(X_train_cont.columns[[item for item in drop_set]])
    
    return(dropcols_featurename)

# %%
X_train_cont.columns = map(str.lower, X_train_cont.columns)
X_train_cont.columns
# Out:
# Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10'],
#       dtype='object')

# %%
drop2 = corr_notok(X_train_cont, cut = 0.4)
print(drop2)
# Out:
# ['cont0', 'cont1', 'cont2', 'cont3', 'cont6', 'cont7', 'cont10']

# %%
#Right code because of the sequential nature of the Python functions. Every decision to drop variables happens in order and is final.

def corr_ok(X_train_cont, cut = 1) :
       
    # Get correlation matrix and lower triagle
    corr_matrix = X_train_cont.corr().abs()
    average_corr = corr_matrix.mean(axis = 1)
    lower_matrix = corr_matrix.where(np.tril(np.ones(corr_matrix.shape), k=1).astype(bool))
    
    dropcols = list()
    
    new_table = pd.DataFrame(columns=(['var1', 'var2', 'v1.target', 
                                 'v2.target','corr_coef', 'drop' ]))
    
    for row in range(len(lower_matrix)-1):
        col_index = row + 1
        for col in range (col_index, len(lower_matrix)):
            if(corr_matrix.iloc[row, col] > cut):
                if(average_corr.iloc[row] > average_corr.iloc[col]): 
                    dropcols.append(row)
                    drop = corr_matrix.columns[row]
                else: 
                    dropcols.append(col)
                    drop = corr_matrix.columns[col]
                
                a = pd.Series([corr_matrix.index[row],
                lower_matrix.columns[col],
                average_corr[row],
                average_corr[col],
                lower_matrix.iloc[row,col],
                drop],
                index = new_table.columns)
        
                new_table = new_table.append(a, ignore_index = True)
    
    dropcols_featurename = calcDrop(new_table)
    
    return(dropcols_featurename)

# %%
def calcDrop(new_table):
    # All variables with correlation > cutoff
    all_corr_vars = list(set(new_table['var1'].tolist() + new_table['var2'].tolist()))
    
    # All unique variables in drop column
    poss_drop = list(set(new_table['drop'].tolist()))

    # Keep any variable not in drop column
    keep = list(set(all_corr_vars).difference(set(poss_drop)))
     
    # Drop any variables in same row as a keep variable
    p = new_table[new_table['var1'].isin(keep)  | new_table['var2'].isin(keep) ][['var1', 'var2']]
    q = list(set(p['var1'].tolist() + p['var2'].tolist()))
    drop = (list(set(q).difference(set(keep))))

    # Remove drop variables from possible drop 
    poss_drop = list(set(poss_drop).difference(set(drop)))
    
    # subset new_table dataframe to include possible drop pairs
    m = new_table[new_table['var1'].isin(poss_drop)  | new_table['var2'].isin(poss_drop) ][['var1', 'var2','drop']]
        
    # remove rows that are decided (drop), take set and add to drops
    moredrops = set(list(m[~m['var1'].isin(drop) & ~m['var2'].isin(drop)]['drop']))
    for item in moredrops:
        drop.append(item)
         
    return drop

# %%
drop = corr_ok(X_train_cont, cut = 0.4)
print(drop)
# Out:
# ['cont10', 'cont6', 'cont7', 'cont0', 'cont1', 'cont2']
